750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 22 persons, 12.6ms
# video 1/1 (frame 490/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 13.3ms
# video 1/1 (frame 491/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 8.6ms
# video 1/1 (frame 492/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 18.9ms
# video 1/1 (frame 493/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 22 persons, 9.3ms
# video 1/1 (frame 494/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 12.5ms
# video 1/1 (frame 495/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 27 persons, 1 truck, 9.2ms
# video 1/1 (frame 496/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 1 truck, 12.1ms
# video 1/1 (frame 497/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 13.0ms
# video 1/1 (frame 498/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 22.4ms
# video 1/1 (frame 499/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 11.2ms
# video 1/1 (frame 500/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 9.1ms
# video 1/1 (frame 501/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 21 persons, 1 car, 8.3ms
# video 1/1 (frame 502/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 1 car, 7.9ms
# video 1/1 (frame 503/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 1 car, 14.2ms
# video 1/1 (frame 504/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 26 persons, 1 car, 12.9ms
# video 1/1 (frame 505/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 21 persons, 15.2ms
# video 1/1 (frame 506/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 26 persons, 15.5ms
# video 1/1 (frame 507/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 20 persons, 21.9ms
# video 1/1 (frame 508/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 14.7ms
# video 1/1 (frame 509/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 23 persons, 10.1ms
# video 1/1 (frame 510/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 20 persons, 7.3ms
# video 1/1 (frame 511/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 22 persons, 14.5ms
# video 1/1 (frame 512/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 19 persons, 9.4ms
# video 1/1 (frame 513/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 16 persons, 10.0ms
# video 1/1 (frame 514/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 16 persons, 8.9ms
# video 1/1 (frame 515/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 18 persons, 12.0ms
# video 1/1 (frame 516/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 24 persons, 8.7ms
# video 1/1 (frame 517/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 25 persons, 10.4ms
# video 1/1 (frame 518/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 20 persons, 11.6ms
# video 1/1 (frame 519/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 19 persons, 7.5ms
# ...
# video 1/1 (frame 744/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 11 persons, 8.4ms
# video 1/1 (frame 745/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 10 persons, 7.8ms
# video 1/1 (frame 746/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 8 persons, 8.4ms
# video 1/1 (frame 747/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 10 persons, 8.3ms
# video 1/1 (frame 748/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 11 persons, 6.4ms
# video 1/1 (frame 749/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 7 persons, 7.0ms
# video 1/1 (frame 750/750) /content/drive/MyDrive/08fd33_4.mp4: 384x640 11 persons, 7.2ms
# Speed: 3.5ms preprocess, 9.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[100, 146, 105],
#         [ 92, 138,  97],
#         [ 97, 150, 101],
#         ...,
#         [100,  92,  82],
#         [103,  95,  85],
#         [105,  97,  87]],
#
#        [[ 99, 145, 104],
#         [ 99, 145, 104],
#         [109, 162, 113],
#         ...,
#         [105,  97,  87],
#         [107,  99,  89],
#         [108, 100,  90]],
#
#        [[ 96, 149, 100],
#         [105, 158, 109],
#         [112, 170, 113],
#         ...,
#         [106,  98,  88],
#         [108, 100,  90],
#         [110, 102,  92]],
#
#        ...,
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 30,  47,  43],
#         [ 31,  48,  44],
#         [ 31,  48,  44]],
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 44,  56,  55],
#         [ 46,  58,  57],
#         [ 46,  58,  57]],
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 48,  60,  59],
#         [ 49,  61,  60],
#         [ 49,  61,  60]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/drive/MyDrive/08fd33_4.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 5.734542000027432, 'inference': 73.58962799997926, 'postprocess': 250.09728300000234}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.7965], device='cuda:0')
# data: tensor([[1.2774e+02, 9.7151e+02, 1.7319e+02, 1.0800e+03, 7.9651e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 150.4667, 1025.7574,   45.4497,  108.4850]], device='cuda:0')
# xywhn: tensor([[0.0784, 0.9498, 0.0237, 0.1004]], device='cuda:0')
# xyxy: tensor([[ 127.7419,  971.5150,  173.1916, 1080.0000]], device='cuda:0')
# xyxyn: tensor([[0.0665, 0.8996, 0.0902, 1.0000]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.7670], device='cuda:0')
# data: tensor([[1.8533e+03, 8.0919e+02, 1.8952e+03, 9.2358e+02, 7.6705e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1874.2570,  866.3868,   41.8748,  114.3964]], device='cuda:0')
# xywhn: tensor([[0.9762, 0.8022, 0.0218, 0.1059]], device='cuda:0')
# xyxy: tensor([[1853.3196,  809.1886, 1895.1943,  923.5850]], device='cuda:0')
# xyxyn: tensor([[0.9653, 0.7492, 0.9871, 0.8552]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.7318], device='cuda:0')
# data: tensor([[590.1877, 588.0628, 630.3294, 672.0125,   0.7318,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[610.2585, 630.0376,  40.1417,  83.9496]], device='cuda:0')
# xywhn: tensor([[0.3178, 0.5834, 0.0209, 0.0777]], device='cuda:0')
# xyxy: tensor([[590.1877, 588.0628, 630.3294, 672.0125]], device='cuda:0')
# xyxyn: tensor([[0.3074, 0.5445, 0.3283, 0.6222]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.7093], device='cuda:0')
# data: tensor([[1.5742e+03, 6.1248e+02, 1.6145e+03, 6.9747e+02, 7.0933e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1594.3704,  654.9755,   40.3135,   84.9826]], device='cuda:0')
# xywhn: tensor([[0.8304, 0.6065, 0.0210, 0.0787]], device='cuda:0')
# xyxy: tensor([[1574.2136,  612.4842, 1614.5271,  697.4668]], device='cuda:0')
# xyxyn: tensor([[0.8199, 0.5671, 0.8409, 0.6458]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.6958], device='cuda:0')
# data: tensor([[221.4446, 514.8201, 254.7177, 596.9376,   0.6958,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[238.0812, 555.8789,  33.2731,  82.1175]], device='cuda:0')
# xywhn: tensor([[0.1240, 0.5147, 0.0173, 0.0760]], device='cuda:0')
# xyxy: tensor([[221.4446, 514.8201, 254.7177, 596.9376]], device='cuda:0')
# xyxyn: tensor([[0.1153, 0.4767, 0.1327, 0.5527]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.6701], device='cuda:0')
# data: tensor([[1.3069e+03, 4.4953e+02, 1.3511e+03, 5.2010e+02, 6.7006e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1329.0061,  484.8177,   44.2793,   70.5702]], device='cuda:0')
# xywhn: tensor([[0.6922, 0.4489, 0.0231, 0.0653]], device='cuda:0')
# xyxy: tensor([[1306.8665,  449.5326, 1351.1458,  520.1028]], device='cuda:0')
# xyxyn: tensor([[0.6807, 0.4162, 0.7037, 0.4816]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5982], device='cuda:0')
# data: tensor([[327.9955, 495.3002, 365.7510, 567.3266,   0.5982,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[346.8733, 531.3134,  37.7556,  72.0264]], device='cuda:0')
# xywhn: tensor([[0.1807, 0.4920, 0.0197, 0.0667]], device='cuda:0')
# xyxy: tensor([[327.9955, 495.3002, 365.7510, 567.3266]], device='cuda:0')
# xyxyn: tensor([[0.1708, 0.4586, 0.1905, 0.5253]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5789], device='cuda:0')
# data: tensor([[3.6087e+02, 7.2089e+02, 3.9311e+02, 8.2575e+02, 5.7893e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[376.9915, 773.3159,  32.2414, 104.8590]], device='cuda:0')
# xywhn: tensor([[0.1963, 0.7160, 0.0168, 0.0971]], device='cuda:0')
# xyxy: tensor([[360.8708, 720.8864, 393.1122, 825.7454]], device='cuda:0')
# xyxyn: tensor([[0.1880, 0.6675, 0.2047, 0.7646]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5427], device='cuda:0')
# data: tensor([[1.0325e+03, 9.2974e+02, 1.0779e+03, 1.0569e+03, 5.4270e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1055.1869,  993.3226,   45.4563,  127.1590]], device='cuda:0')
# xywhn: tensor([[0.5496, 0.9197, 0.0237, 0.1177]], device='cuda:0')
# xyxy: tensor([[1032.4587,  929.7431, 1077.9150, 1056.9021]], device='cuda:0')
# xyxyn: tensor([[0.5377, 0.8609, 0.5614, 0.9786]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5359], device='cuda:0')
# data: tensor([[1.2765e+03, 3.9273e+02, 1.3064e+03, 4.6756e+02, 5.3593e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1291.4695,  430.1422,   29.8766,   74.8334]], device='cuda:0')
# xywhn: tensor([[0.6726, 0.3983, 0.0156, 0.0693]], device='cuda:0')
# xyxy: tensor([[1276.5311,  392.7255, 1306.4077,  467.5589]], device='cuda:0')
# xyxyn: tensor([[0.6649, 0.3636, 0.6804, 0.4329]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5330], device='cuda:0')
# data: tensor([[5.3099e+02, 6.8548e+02, 5.7828e+02, 7.8940e+02, 5.3296e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[554.6365, 737.4421,  47.2872, 103.9255]], device='cuda:0')
# xywhn: tensor([[0.2889, 0.6828, 0.0246, 0.0962]], device='cuda:0')
# xyxy: tensor([[530.9929, 685.4793, 578.2802, 789.4048]], device='cuda:0')
# xyxyn: tensor([[0.2766, 0.6347, 0.3012, 0.7309]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5065], device='cuda:0')
# data: tensor([[1.3730e+03, 8.1659e+02, 1.4451e+03, 8.9902e+02, 5.0652e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1409.0643,  857.8024,   72.1467,   82.4257]], device='cuda:0')
# xywhn: tensor([[0.7339, 0.7943, 0.0376, 0.0763]], device='cuda:0')
# xyxy: tensor([[1372.9910,  816.5896, 1445.1377,  899.0153]], device='cuda:0')
# xyxyn: tensor([[0.7151, 0.7561, 0.7527, 0.8324]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5027], device='cuda:0')
# data: tensor([[1.2313e+03, 4.3476e+02, 1.2650e+03, 5.0210e+02, 5.0267e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1248.1578,  468.4265,   33.6169,   67.3375]], device='cuda:0')
# xywhn: tensor([[0.6501, 0.4337, 0.0175, 0.0623]], device='cuda:0')
# xyxy: tensor([[1231.3494,  434.7578, 1264.9663,  502.0953]], device='cuda:0')
# xyxyn: tensor([[0.6413, 0.4026, 0.6588, 0.4649]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.4660], device='cuda:0')
# data: tensor([[6.9087e+02, 9.9368e+02, 7.2977e+02, 1.0800e+03, 4.6598e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 710.3196, 1036.8396,   38.9000,   86.3207]], device='cuda:0')
# xywhn: tensor([[0.3700, 0.9600, 0.0203, 0.0799]], device='cuda:0')
# xyxy: tensor([[ 690.8696,  993.6793,  729.7696, 1080.0000]], device='cuda:0')
# xyxyn: tensor([[0.3598, 0.9201, 0.3801, 1.0000]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.4568], device='cuda:0')
# data: tensor([[7.7242e+02, 3.7628e+02, 8.0679e+02, 4.9569e+02, 4.5677e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[789.6042, 435.9825,  34.3619, 119.4064]], device='cuda:0')
# xywhn: tensor([[0.4113, 0.4037, 0.0179, 0.1106]], device='cuda:0')
# xyxy: tensor([[772.4233, 376.2794, 806.7852, 495.6857]], device='cuda:0')
# xyxyn: tensor([[0.4023, 0.3484, 0.4202, 0.4590]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.4373], device='cuda:0')
# data: tensor([[9.9631e+02, 4.5759e+02, 1.0271e+03, 5.2510e+02, 4.3729e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1011.7275,  491.3476,   30.8350,   67.5072]], device='cuda:0')
# xywhn: tensor([[0.5269, 0.4550, 0.0161, 0.0625]], device='cuda:0')
# xyxy: tensor([[ 996.3101,  457.5940, 1027.1450,  525.1012]], device='cuda:0')
# xyxyn: tensor([[0.5189, 0.4237, 0.5350, 0.4862]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.4216], device='cuda:0')
# data: tensor([[1.1221e+03, 7.0823e+02, 1.1979e+03, 7.9716e+02, 4.2165e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1159.9641,  752.6943,   75.7936,   88.9371]], device='cuda:0')
# xywhn: tensor([[0.6041, 0.6969, 0.0395, 0.0823]], device='cuda:0')
# xyxy: tensor([[1122.0674,  708.2258, 1197.8610,  797.1628]], device='cuda:0')
# xyxyn: tensor([[0.5844, 0.6558, 0.6239, 0.7381]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3695], device='cuda:0')
# data: tensor([[8.7655e+02, 3.6281e+02, 9.0431e+02, 4.2101e+02, 3.6950e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[890.4307, 391.9102,  27.7683,  58.2078]], device='cuda:0')
# xywhn: tensor([[0.4638, 0.3629, 0.0145, 0.0539]], device='cuda:0')
# xyxy: tensor([[876.5466, 362.8064, 904.3149, 421.0141]], device='cuda:0')
# xyxyn: tensor([[0.4565, 0.3359, 0.4710, 0.3898]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3653], device='cuda:0')
# data: tensor([[3.7602e+02, 3.0453e+02, 4.0190e+02, 3.6302e+02, 3.6527e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[388.9597, 333.7739,  25.8775,  58.4842]], device='cuda:0')
# xywhn: tensor([[0.2026, 0.3090, 0.0135, 0.0542]], device='cuda:0')
# xyxy: tensor([[376.0210, 304.5318, 401.8985, 363.0160]], device='cuda:0')
# xyxyn: tensor([[0.1958, 0.2820, 0.2093, 0.3361]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3478], device='cuda:0')
# data: tensor([[1.9012e+03, 3.7972e+02, 1.9192e+03, 4.4582e+02, 3.4781e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1910.2083,  412.7734,   18.0081,   66.0972]], device='cuda:0')
# xywhn: tensor([[0.9949, 0.3822, 0.0094, 0.0612]], device='cuda:0')
# xyxy: tensor([[1901.2042,  379.7248, 1919.2123,  445.8220]], device='cuda:0')
# xyxyn: tensor([[0.9902, 0.3516, 0.9996, 0.4128]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.3344], device='cuda:0')
# data: tensor([[1.1589e+03, 3.5891e+02, 1.1866e+03, 4.1533e+02, 3.3438e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1172.7200,  387.1195,   27.6918,   56.4257]], device='cuda:0')
# xywhn: tensor([[0.6108, 0.3584, 0.0144, 0.0522]], device='cuda:0')
# xyxy: tensor([[1158.8741,  358.9066, 1186.5659,  415.3323]], device='cuda:0')
# xyxyn: tensor([[0.6036, 0.3323, 0.6180, 0.3846]], device='cuda:0')

# %% [markdown]
# Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mqaNYJIWtgxvD6TAXNNg")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:09<00:00, 15360.94it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2891.77it/s]

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
import shutil

shutil.move("/content/football-players-detection-1/train",
            "/content/drive/MyDrive/football-detection/train")

shutil.move("/content/football-players-detection-1/test",
            "/content/drive/MyDrive/football-detection/test")

shutil.move("/content/football-players-detection-1/valid",
            "/content/drive/MyDrive/football-detection/valid")
# Out:
# '/content/drive/MyDrive/football-detection/valid'

# %% [markdown]
# ##Training

# %%
# !yolo task=detect mode=train model=yolov5l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1/755.1KB 21.5MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#   9                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  10                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  14                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  21                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3, False]
#  24        [17, 20, 23]  1   7060444  ultralytics.nn.modules.head.Detect           [4, [256, 512, 1024]]
# YOLOv5l summary: 241 layers, 53,166,428 parameters, 53,166,412 gradients, 135.3 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 88.7MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 100.1±22.3 MB/s, size: 228.7 KB)
# train: Scanning /content/drive/MyDrive/football-detection/train/labels... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 90.7it/s 6.7s
# train: New cache created: /content/drive/MyDrive/football-detection/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.5±2.6 ms, read: 63.4±23.9 MB/s, size: 208.1 KB)
# val: Scanning /content/drive/MyDrive/football-detection/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 77.4it/s 0.5s
# val: New cache created: /content/drive/MyDrive/football-detection/valid/labels.cache
# Plotting labels to runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      9.55G      1.223      1.433     0.8365        156        640: 100% ━━━━━━━━━━━━ 39/39 1.2it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.6s
#                    all         38        905      0.735       0.45      0.491      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      10.2G      1.169     0.7333      0.816        146        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 27.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         38        905      0.689      0.601       0.62      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      9.92G      1.234     0.6945     0.8155        158        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         38        905      0.428      0.639      0.344      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      9.96G      1.222     0.6481     0.8144        194        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         38        905       0.69      0.618      0.664      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100        10G      1.182      0.644     0.8088        202        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         38        905      0.844       0.67      0.731      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      10.1G      1.123     0.5781     0.8079        221        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         38        905      0.755      0.625      0.658      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      10.2G      1.119     0.5726     0.8073        176        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         38        905      0.664      0.547      0.586      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100        10G      1.115     0.5839     0.8035        161        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         38        905      0.855      0.672      0.716      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      9.91G      1.027     0.5514     0.7993        125        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         38        905      0.867      0.672      0.729      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      10.1G      1.033     0.5319     0.7998         97        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         38        905      0.872      0.608      0.707      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      10.3G      1.032     0.5189     0.7986        224        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         38        905      0.845      0.684      0.727      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      10.4G      1.014     0.5038     0.7971        184        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         38        905      0.865      0.694      0.759      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       9.9G      1.059     0.5222      0.799        170        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         38        905      0.763      0.605      0.671        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      10.1G      1.068     0.5471     0.7998        164        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         38        905      0.787       0.64      0.693      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      10.2G     0.9767     0.4861     0.7959        192        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         38        905      0.916      0.704      0.786      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      9.97G     0.9623     0.4765     0.7948        177        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         38        905      0.884      0.735      0.774      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      9.88G     0.9496     0.4645     0.7934        113        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         38        905      0.891      0.711      0.769      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      9.88G     0.9228     0.4495     0.7915        223        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         38        905      0.917      0.713      0.779      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      10.2G      0.967     0.4584     0.7933        231        640: 100% ━━━━━━━━━━━━ 39/39 1.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         38        905      0.837      0.717      0.776      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      10.3G     0.9466       0.45     0.7911        257        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         38        905      0
0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      10.3G     0.5833     0.2846     0.7716         92        640: 100% ━━━━━━━━━━━━ 39/39 1.4it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         38        905      0.956      0.755      0.819      0.591
#
# 100 epochs completed in 1.041 hours.
# Optimizer stripped from runs/detect/train4/weights/last.pt, 106.8MB
# Optimizer stripped from runs/detect/train4/weights/best.pt, 106.8MB
#
# Validating runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5l summary (fused): 128 layers, 53,134,492 parameters, 0 gradients, 134.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         38        905      0.958       0.75       0.82      0.591
#                   ball         35         35          1      0.226      0.386       0.17
#             goalkeeper         27         27      0.917      0.926      0.973      0.744
#                 player         38        754      0.974      0.959      0.987        0.8
#                referee         38         89      0.941      0.889      0.935      0.648
# Speed: 0.1ms preprocess, 9.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train4
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
from ultralytics import YOLO

model=YOLO('/content/drive/MyDrive/football-detection/best.pt')
results=model.predict("/content/drive/MyDrive/football-detection/08fd33_4.mp4",save=True)
print(results[0])
for box in results[0].boxes:
  print(box )
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 17 players, 3 referees, 102.4ms
# video 1/1 (frame 2/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 17 players, 3 referees, 38.2ms
# video 1/1 (frame 3/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 18 players, 3 referees, 38.2ms
# video 1/1 (frame 4/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 22 players, 3 referees, 38.2ms
# video 1/1 (frame 5/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 37.8ms
# video 1/1 (frame 6/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 19 players, 3 referees, 35.1ms
# video 1/1 (frame 7/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 3 referees, 35.1ms
# video 1/1 (frame 8/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 22 players, 3 referees, 32.6ms
# video 1/1 (frame 9/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 3 goalkeepers, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 10/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 32.6ms
# video 1/1 (frame 11/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 19 players, 3 referees, 32.7ms
# video 1/1 (frame 12/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 32.6ms
# video 1/1 (frame 13/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 32.6ms
# video 1/1 (frame 14/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 32.5ms
# video 1/1 (frame 15/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 29 players, 3 referees, 32.6ms
# video 1/1 (frame 16/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 32.6ms
# video 1/1 (frame 17/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 19 players, 3 referees, 32.5ms
# video 1/1 (frame 18/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 19 players, 3 referees, 32.6ms
# video 1/1 (frame 19/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 20/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 25 players, 3 referees, 32.5ms
# video 1/1 (frame 21/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 22/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 23/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 24/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 32.6ms
# video 1/1 (frame 25/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 32.6ms
# video 1/1 (frame 26/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 3 referees, 33.9ms
# video 1/1 (frame 27/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 34.4ms
# video 1/1 (frame 28/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 33.3ms
# video 1/1 (frame 29/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.0ms
# video 1/1 (frame 30/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.4ms
# video 1/1 (frame 31/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 21 players, 3 referees, 32.0ms
# video 1/1 (frame 32/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 21 players, 3 referees, 32.2ms
# video 1/1 (frame 33/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.1ms
# video 1/1 (frame 34/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 34 players, 15 referees, 38.4ms
# video 1/1 (frame 35/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 3 balls, 49 players, 16 referees, 32.9ms
# video 1/1 (frame 36/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.0ms
# video 1/1 (frame 37/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 4 referees, 32.0ms
# video 1/1 (frame 38/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.7ms
# video 1/1 (frame 39/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 21 players, 4 referees, 39.2ms
# video 1/1 (frame 40/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.0ms
# video 1/1 (frame 41/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 2 balls, 20 players, 3 referees, 32.0ms
# video 1/1 (frame 42/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees,
750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 33 players, 2 referees, 30.0ms
# video 1/1 (frame 353/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 39 players, 3 referees, 30.0ms
# video 1/1 (frame 354/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 19 players, 3 referees, 30.0ms
# video 1/1 (frame 355/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 27 players, 3 referees, 30.0ms
# video 1/1 (frame 356/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 24 players, 3 referees, 30.0ms
# video 1/1 (frame 357/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 2 goalkeepers, 50 players, 4 referees, 30.0ms
# video 1/1 (frame 358/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 22 players, 3 referees, 30.0ms
# video 1/1 (frame 359/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 18 players, 3 referees, 30.0ms
# video 1/1 (frame 360/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 19 players, 3 referees, 30.0ms
# video 1/1 (frame 361/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 51 players, 3 referees, 30.0ms
# video 1/1 (frame 362/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 65 players, 12 referees, 29.9ms
# video 1/1 (frame 363/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 39 players, 5 referees, 29.9ms
# video 1/1 (frame 364/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 65 players, 13 referees, 30.4ms
# video 1/1 (frame 365/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 25 players, 3 referees, 30.4ms
# video 1/1 (frame 366/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 21 players, 3 referees, 30.9ms
# video 1/1 (frame 367/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 33 players, 3 referees, 30.9ms
# video 1/1 (frame 368/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 36 players, 3 referees, 31.5ms
# video 1/1 (frame 369/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 55 players, 4 referees, 31.5ms
# video 1/1 (frame 370/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 65 players, 14 referees, 31.4ms
# video 1/1 (frame 371/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 ball, 52 players, 4 referees, 31.5ms
# video 1/1 (frame 372/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 20 players, 2 referees, 32.0ms
# video 1/1 (frame 373/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 51 players, 4 referees, 32.0ms
# video 1/1 (frame 374/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 53 players, 6 referees, 32.4ms
# video 1/1 (frame 375/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 64 players, 15 referees, 32.6ms
# video 1/1 (frame 376/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 19 players, 3 referees, 32.5ms
# ...
# video 1/1 (frame 742/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 41 players, 10 referees, 35.8ms
# video 1/1 (frame 743/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 3 referees, 35.8ms
# video 1/1 (frame 744/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 3 goalkeepers, 71 players, 11 referees, 35.8ms
# video 1/1 (frame 745/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 3 referees, 35.8ms
# video 1/1 (frame 746/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 3 referees, 35.9ms
# video 1/1 (frame 747/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 3 referees, 35.8ms
# video 1/1 (frame 748/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 20 players, 4 referees, 35.9ms
# video 1/1 (frame 749/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 22 players, 2 referees, 35.7ms
# video 1/1 (frame 750/750) /content/drive/MyDrive/football-detection/08fd33_4.mp4: 384x640 1 goalkeeper, 21 players, 3 referees, 35.8ms
# Speed: 3.5ms preprocess, 33.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
# obb: None
# orig_img: array([[[100, 146, 105],
#         [ 92, 138,  97],
#         [ 97, 150, 101],
#         ...,
#         [100,  92,  82],
#         [103,  95,  85],
#         [105,  97,  87]],
#
#        [[ 99, 145, 104],
#         [ 99, 145, 104],
#         [109, 162, 113],
#         ...,
#         [105,  97,  87],
#         [107,  99,  89],
#         [108, 100,  90]],
#
#        [[ 96, 149, 100],
#         [105, 158, 109],
#         [112, 170, 113],
#         ...,
#         [106,  98,  88],
#         [108, 100,  90],
#         [110, 102,  92]],
#
#        ...,
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 30,  47,  43],
#         [ 31,  48,  44],
#         [ 31,  48,  44]],
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 44,  56,  55],
#         [ 46,  58,  57],
#         [ 46,  58,  57]],
#
#        [[ 74, 103,  78],
#         [ 74, 103,  78],
#         [ 74, 103,  78],
#         ...,
#         [ 48,  60,  59],
#         [ 49,  61,  60],
#         [ 49,  61,  60]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/drive/MyDrive/football-detection/08fd33_4.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 6.361257999969894, 'inference': 102.36107499997615, 'postprocess': 358.3993519999922}
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9321], device='cuda:0')
# data: tensor([[1.3689e+03, 8.1652e+02, 1.4429e+03, 9.0297e+02, 9.3205e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1405.9146,  859.7479,   73.9917,   86.4512]], device='cuda:0')
# xywhn: tensor([[0.7322, 0.7961, 0.0385, 0.0800]], device='cuda:0')
# xyxy: tensor([[1368.9187,  816.5223, 1442.9104,  902.9735]], device='cuda:0')
# xyxyn: tensor([[0.7130, 0.7560, 0.7515, 0.8361]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9315], device='cuda:0')
# data: tensor([[848.2667, 634.7668, 901.7298, 720.2155,   0.9315,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[874.9982, 677.4911,  53.4631,  85.4486]], device='cuda:0')
# xywhn: tensor([[0.4557, 0.6273, 0.0278, 0.0791]], device='cuda:0')
# xyxy: tensor([[848.2667, 634.7668, 901.7298, 720.2155]], device='cuda:0')
# xyxyn: tensor([[0.4418, 0.5877, 0.4697, 0.6669]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9224], device='cuda:0')
# data: tensor([[1.3085e+03, 4.4739e+02, 1.3514e+03, 5.1595e+02, 9.2238e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1329.9438,  481.6722,   42.8456,   68.5578]], device='cuda:0')
# xywhn: tensor([[0.6927, 0.4460, 0.0223, 0.0635]], device='cuda:0')
# xyxy: tensor([[1308.5211,  447.3933, 1351.3667,  515.9511]], device='cuda:0')
# xyxyn: tensor([[0.6815, 0.4143, 0.7038, 0.4777]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9222], device='cuda:0')
# data: tensor([[9.9518e+02, 4.5365e+02, 1.0267e+03, 5.2670e+02, 9.2215e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1010.9287,  490.1743,   31.5043,   73.0505]], device='cuda:0')
# xywhn: tensor([[0.5265, 0.4539, 0.0164, 0.0676]], device='cuda:0')
# xyxy: tensor([[ 995.1766,  453.6491, 1026.6809,  526.6996]], device='cuda:0')
# xyxyn: tensor([[0.5183, 0.4200, 0.5347, 0.4877]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9206], device='cuda:0')
# data: tensor([[1.5720e+03, 6.1146e+02, 1.6133e+03, 6.9467e+02, 9.2064e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1592.6353,  653.0640,   41.3430,   83.2159]], device='cuda:0')
# xywhn: tensor([[0.8295, 0.6047, 0.0215, 0.0771]], device='cuda:0')
# xyxy: tensor([[1571.9637,  611.4561, 1613.3068,  694.6719]], device='cuda:0')
# xyxyn: tensor([[0.8187, 0.5662, 0.8403, 0.6432]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9205], device='cuda:0')
# data: tensor([[329.0419, 495.1676, 364.9371, 568.3589,   0.9205,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[346.9895, 531.7632,  35.8952,  73.1913]], device='cuda:0')
# xywhn: tensor([[0.1807, 0.4924, 0.0187, 0.0678]], device='cuda:0')
# xyxy: tensor([[329.0419, 495.1676, 364.9371, 568.3589]], device='cuda:0')
# xyxyn: tensor([[0.1714, 0.4585, 0.1901, 0.5263]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9177], device='cuda:0')
# data: tensor([[872.2133, 361.6361, 904.6774, 423.2070,   0.9177,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[888.4453, 392.4216,  32.4641,  61.5709]], device='cuda:0')
# xywhn: tensor([[0.4627, 0.3634, 0.0169, 0.0570]], device='cuda:0')
# xyxy: tensor([[872.2133, 361.6361, 904.6774, 423.2070]], device='cuda:0')
# xyxyn: tensor([[0.4543, 0.3348, 0.4712, 0.3919]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9175], device='cuda:0')
# data: tensor([[533.5686, 686.9574, 578.6477, 785.3973,   0.9175,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[556.1082, 736.1774,  45.0791,  98.4399]], device='cuda:0')
# xywhn: tensor([[0.2896, 0.6816, 0.0235, 0.0911]], device='cuda:0')
# xyxy: tensor([[533.5686, 686.9574, 578.6477, 785.3973]], device='cuda:0')
# xyxyn: tensor([[0.2779, 0.6361, 0.3014, 0.7272]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9138], device='cuda:0')
# data: tensor([[222.6455, 513.2980, 256.0100, 595.0685,   0.9138,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[239.3278, 554.1832,  33.3645,  81.7705]], device='cuda:0')
# xywhn: tensor([[0.1246, 0.5131, 0.0174, 0.0757]], device='cuda:0')
# xyxy: tensor([[222.6455, 513.2980, 256.0100, 595.0685]], device='cuda:0')
# xyxyn: tensor([[0.1160, 0.4753, 0.1333, 0.5510]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9106], device='cuda:0')
# data: tensor([[586.8671, 589.7463, 630.8432, 672.0889,   0.9106,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[608.8552, 630.9176,  43.9761,  82.3425]], device='cuda:0')
# xywhn: tensor([[0.3171, 0.5842, 0.0229, 0.0762]], device='cuda:0')
# xyxy: tensor([[586.8671, 589.7463, 630.8432, 672.0889]], device='cuda:0')
# xyxyn: tensor([[0.3057, 0.5461, 0.3286, 0.6223]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9081], device='cuda:0')
# data: tensor([[1.2294e+03, 4.3004e+02, 1.2632e+03, 5.0094e+02, 9.0805e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1246.2874,  465.4884,   33.8654,   70.8957]], device='cuda:0')
# xywhn: tensor([[0.6491, 0.4310, 0.0176, 0.0656]], device='cuda:0')
# xyxy: tensor([[1229.3546,  430.0406, 1263.2200,  500.9363]], device='cuda:0')
# xyxyn: tensor([[0.6403, 0.3982, 0.6579, 0.4638]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9071], device='cuda:0')
# data: tensor([[1.2761e+03, 3.9262e+02, 1.3071e+03, 4.6122e+02, 9.0708e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1291.6187,  426.9191,   31.0162,   68.5974]], device='cuda:0')
# xywhn: tensor([[0.6727, 0.3953, 0.0162, 0.0635]], device='cuda:0')
# xyxy: tensor([[1276.1105,  392.6204, 1307.1267,  461.2178]], device='cuda:0')
# xyxyn: tensor([[0.6646, 0.3635, 0.6808, 0.4271]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.9067], device='cuda:0')
# data: tensor([[1.8525e+03, 8.0909e+02, 1.8939e+03, 9.1832e+02, 9.0665e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1873.1858,  863.7076,   41.4163,  109.2312]], device='cuda:0')
# xywhn: tensor([[0.9756, 0.7997, 0.0216, 0.1011]], device='cuda:0')
# xyxy: tensor([[1852.4777,  809.0920, 1893.8939,  918.3232]], device='cuda:0')
# xyxyn: tensor([[0.9648, 0.7492, 0.9864, 0.8503]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9038], device='cuda:0')
# data: tensor([[359.4871, 721.1794, 392.6011, 823.6864,   0.9038,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[376.0441, 772.4329,  33.1141, 102.5070]], device='cuda:0')
# xywhn: tensor([[0.1959, 0.7152, 0.0172, 0.0949]], device='cuda:0')
# xyxy: tensor([[359.4871, 721.1794, 392.6011, 823.6864]], device='cuda:0')
# xyxyn: tensor([[0.1872, 0.6678, 0.2045, 0.7627]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9016], device='cuda:0')
# data: tensor([[374.7359, 305.9626, 400.8367, 365.7742,   0.9016,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[387.7863, 335.8684,  26.1008,  59.8116]], device='cuda:0')
# xywhn: tensor([[0.2020, 0.3110, 0.0136, 0.0554]], device='cuda:0')
# xyxy: tensor([[374.7359, 305.9626, 400.8367, 365.7742]], device='cuda:0')
# xyxyn: tensor([[0.1952, 0.2833, 0.2088, 0.3387]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.8974], device='cuda:0')
# data: tensor([[775.9144, 417.0307, 804.3946, 490.0107,   0.8974,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[790.1545, 453.5207,  28.4802,  72.9800]], device='cuda:0')
# xywhn: tensor([[0.4115, 0.4199, 0.0148, 0.0676]], device='cuda:0')
# xyxy: tensor([[775.9144, 417.0307, 804.3946, 490.0107]], device='cuda:0')
# xyxyn: tensor([[0.4041, 0.3861, 0.4190, 0.4537]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.8825], device='cuda:0')
# data: tensor([[776.7761, 367.9398, 801.8209, 429.1867,   0.8825,   3.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[789.2985, 398.5632,  25.0448,  61.2469]], device='cuda:0')
# xywhn: tensor([[0.4111, 0.3690, 0.0130, 0.0567]], device='cuda:0')
# xyxy: tensor([[776.7761, 367.9398, 801.8209, 429.1867]], device='cuda:0')
# xyxyn: tensor([[0.4046, 0.3407, 0.4176, 0.3974]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.8821], device='cuda:0')
# data: tensor([[1.1611e+03, 3.5512e+02, 1.1884e+03, 4.1257e+02, 8.8207e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1174.7515,  383.8445,   27.2373,   57.4497]], device='cuda:0')
# xywhn: tensor([[0.6118, 0.3554, 0.0142, 0.0532]], device='cuda:0')
# xyxy: tensor([[1161.1328,  355.1196, 1188.3701,  412.5693]], device='cuda:0')
# xyxyn: tensor([[0.6048, 0.3288, 0.6189, 0.3820]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.8549], device='cuda:0')
# data: tensor([[1.1237e+03, 7.0615e+02, 1.1941e+03, 7.9550e+02, 8.5491e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1158.9172,  750.8210,   70.3534,   89.3510]], device='cuda:0')
# xywhn: tensor([[0.6036, 0.6952, 0.0366, 0.0827]], device='cuda:0')
# xyxy: tensor([[1123.7406,  706.1456, 1194.0940,  795.4966]], device='cuda:0')
# xyxyn: tensor([[0.5853, 0.6538, 0.6219, 0.7366]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.8538], device='cuda:0')
# data: tensor([[1.9026e+03, 3.7323e+02, 1.9200e+03, 4.4343e+02, 8.5380e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1911.2795,  408.3304,   17.4408,   70.2078]], device='cuda:0')
# xywhn: tensor([[0.9955, 0.3781, 0.0091, 0.0650]], device='cuda:0')
# xyxy: tensor([[1902.5592,  373.2265, 1920.0000,  443.4343]], device='cuda:0')
# xyxyn: tensor([[0.9909, 0.3456, 1.0000, 0.4106]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.8245], device='cuda:0')
# data: tensor([[310.1353, 227.1001, 327.7949, 271.7756,   0.8245,   3.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[318.9651, 249.4379,  17.6596,  44.6754]], device='cuda:0')
# xywhn: tensor([[0.1661, 0.2310, 0.0092, 0.0414]], device='cuda:0')
# xyxy: tensor([[310.1353, 227.1001, 327.7949, 271.7756]], device='cuda:0')
# xyxyn: tensor([[0.1615, 0.2103, 0.1707, 0.2516]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.6453], device='cuda:0')
# data: tensor([[1.1862e+03, 8.5000e+02, 1.2039e+03, 8.6747e+02, 6.4528e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1195.0968,  858.7348,   17.6985,   17.4672]], device='cuda:0')
# xywhn: tensor([[0.6224, 0.7951, 0.0092, 0.0162]], device='cuda:0')
# xyxy: tensor([[1186.2476,  850.0012, 1203.9460,  867.4684]], device='cuda:0')
# xyxyn: tensor([[0.6178, 0.7870, 0.6271, 0.8032]], device='cuda:0')

# %%
# !pip install supervision
# Out:
# Collecting supervision
#   Downloading supervision-0.26.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (1.16.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.12/dist-packages (from supervision) (11.3.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.12.0.88)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Downloading supervision-0.26.1-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.2/207.2 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: supervision
# Successfully installed supervision-0.26.1

# %%
import cv2

def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    return frames

def save_video(ouput_video_frames,output_video_path):
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, 24, (ouput_video_frames[0].shape[1], ouput_video_frames[0].shape[0]))
    for frame in ouput_video_frames:
        out.write(frame)
    out.release()

def get_center_of_bbox(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2),int((y1+y2)/2)

def get_bbox_width(bbox):
    return bbox[2]-bbox[0]

def measure_distance(p1,p2):
    return ((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)**0.5

def measure_xy_distance(p1,p2):
    return p1[0]-p2[0],p1[1]-p2[1]

def get_foot_position(bbox):
    x1,y1,x2,y2 = bbox
    return int((x1+x2)/2),int(y2)

# %%
import sys
sys.path.append('../')

class PlayerBallAssigner():
    def __init__(self):
        self.max_player_ball_distance = 70

    def assign_ball_to_player(self,players,ball_bbox):
        ball_position = get_center_of_bbox(ball_bbox)

        miniumum_distance = 99999
        assigned_player=-1

        for player_id, player in players.items():
            player_bbox = player['bbox']

            distance_left = measure_distance((player_bbox[0],player_bbox[-1]),ball_position)
            distance_right = measure_distance((player_bbox[2],player_bbox[-1]),ball_position)
            distance = min(distance_left,distance_right)

            if distance < self.max_player_ball_distance:
                if distance < miniumum_distance:
                    miniumum_distance = distance
                    assigned_player = player_id

        return assigned_player

# %%
from sklearn.cluster import KMeans

class TeamAssigner:
    def __init__(self):
        self.team_colors = {}
        self.player_team_dict = {}

    def get_clustering_model(self,image):
        # Reshape the image to 2D array
        image_2d = image.reshape(-1,3)

        # Preform K-means with 2 clusters
        kmeans = KMeans(n_clusters=2, init="k-means++",n_init=1)
        kmeans.fit(image_2d)

        return kmeans

    def get_player_color(self,frame,bbox):
        image = frame[int(bbox[1]):int(bbox[3]),int(bbox[0]):int(bbox[2])]

        top_half_image = image[0:int(image.shape[0]/2),:]

        # Get Clustering model
        kmeans = self.get_clustering_model(top_half_image)

        # Get the cluster labels forr each pixel
        labels = kmeans.labels_

        # Reshape the labels to the image shape
        clustered_image = labels.reshape(top_half_image.shape[0],top_half_image.shape[1])

        # Get the player cluster
        corner_clusters = [clustered_image[0,0],clustered_image[0,-1],clustered_image[-1,0],clustered_image[-1,-1]]
        non_player_cluster = max(set(corner_clusters),key=corner_clusters.count)
        player_cluster = 1 - non_player_cluster

        player_color = kmeans.cluster_centers_[player_cluster]

        return player_color


    def assign_team_color(self,frame, player_detections):

        player_colors = []
        for _, player_detection in player_detections.items():
            bbox = player_detection["bbox"]
            player_color =  self.get_player_color(frame,bbox)
            player_colors.append(player_color)

        kmeans = KMeans(n_clusters=2, init="k-means++",n_init=10)
        kmeans.fit(player_colors)

        self.kmeans = kmeans

        self.team_colors[1] = kmeans.cluster_centers_[0]
        self.team_colors[2] = kmeans.cluster_centers_[1]


    def get_player_team(self,frame,player_bbox,player_id):
        if player_id in self.player_team_dict:
            return self.player_team_dict[player_id]

        player_color = self.get_player_color(frame,player_bbox)

        team_id = self.kmeans.predict(player_color.reshape(1,-1))[0]
        team_id+=1

        if player_id ==91:
            team_id=1

        self.player_team_dict[player_id] = team_id

        return team_id

# %%
import numpy as np
import cv2

class ViewTransformer():
    def __init__(self):
        court_width = 68
        court_length = 23.32

        self.pixel_vertices = np.array([[110, 1035],
                               [265, 275],
                               [910, 260],
                               [1640, 915]])

        self.target_vertices = np.array([
            [0,court_width],
            [0, 0],
            [court_length, 0],
            [court_length, court_width]
        ])

        self.pixel_vertices = self.pixel_vertices.astype(np.float32)
        self.target_vertices = self.target_vertices.astype(np.float32)

        self.persepctive_trasnformer = cv2.getPerspectiveTransform(self.pixel_vertices, self.target_vertices)

    def transform_point(self,point):
        p = (int(point[0]),int(point[1]))
        is_inside = cv2.pointPolygonTest(self.pixel_vertices,p,False) >= 0
        if not is_inside:
            return None

        reshaped_point = point.reshape(-1,1,2).astype(np.float32)
        tranform_point = cv2.perspectiveTransform(reshaped_point,self.persepctive_trasnformer)
        return tranform_point.reshape(-1,2)

    def add_transformed_position_to_tracks(self,tracks):
        for object, object_tracks in tracks.items():
            for frame_num, track in enumerate(object_tracks):
                for track_id, track_info in track.items():
                    position = track_info['position_adjusted']
                    position = np.array(position)
                    position_trasnformed = self.transform_point(position)
                    if position_trasnformed is not None:
                        position_trasnformed = position_trasnformed.squeeze().tolist()
                    tracks[object][frame_num][track_id]['position_transformed'] = position_trasnformed

# %%
import pickle
import cv2
import numpy as np
import os
import sys
sys.path.append('../')

class CameraMovementEstimator():
    def __init__(self,frame):
        self.minimum_distance = 5

        self.lk_params = dict(
            winSize = (15,15),
            maxLevel = 2,
            criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT,10,0.03)
        )

        first_frame_grayscale = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        mask_features = np.zeros_like(first_frame_grayscale)
        mask_features[:,0:20] = 1
        mask_features[:,900:1050] = 1

        self.features = dict(
            maxCorners = 100,
            qualityLevel = 0.3,
            minDistance =3,
            blockSize = 7,
            mask = mask_features
        )

    def add_adjust_positions_to_tracks(self,tracks, camera_movement_per_frame):
        for object, object_tracks in tracks.items():
            for frame_num, track in enumerate(object_tracks):
                for track_id, track_info in track.items():
                    position = track_info['position']
                    camera_movement = camera_movement_per_frame[frame_num]
                    position_adjusted = (position[0]-camera_movement[0],position[1]-camera_movement[1])
                    tracks[object][frame_num][track_id]['position_adjusted'] = position_adjusted



    def get_camera_movement(self,frames,read_from_stub=False, stub_path=None):
        # Read the stub
        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                return pickle.load(f)

        camera_movement = [[0,0]]*len(frames)

        old_gray = cv2.cvtColor(frames[0],cv2.COLOR_BGR2GRAY)
        old_features = cv2.goodFeaturesToTrack(old_gray,**self.features)

        for frame_num in range(1,len(frames)):
            frame_gray = cv2.cvtColor(frames[frame_num],cv2.COLOR_BGR2GRAY)
            new_features, _,_ = cv2.calcOpticalFlowPyrLK(old_gray,frame_gray,old_features,None,**self.lk_params)

            max_distance = 0
            camera_movement_x, camera_movement_y = 0,0

            for i, (new,old) in enumerate(zip(new_features,old_features)):
                new_features_point = new.ravel()
                old_features_point = old.ravel()

                distance = measure_distance(new_features_point,old_features_point)
                if distance>max_distance:
                    max_distance = distance
                    camera_movement_x,camera_movement_y = measure_xy_distance(old_features_point, new_features_point )

            if max_distance > self.minimum_distance:
                camera_movement[frame_num] = [camera_movement_x,camera_movement_y]
                old_features = cv2.goodFeaturesToTrack(frame_gray,**self.features)

            old_gray = frame_gray.copy()

        if stub_path is not None:
            os.makedirs(os.path.dirname(stub_path), exist_ok=True)
            with open(stub_path,'wb') as f:
                pickle.dump(camera_movement,f)

        return camera_movement

    def draw_camera_movement(self,frames, camera_movement_per_frame):
        output_frames=[]

        for frame_num, frame in enumerate(frames):
            frame= frame.copy()

            overlay = frame.copy()
            cv2.rectangle(overlay,(0,0),(500,100),(255,255,255),-1)
            alpha =0.6
            cv2.addWeighted(overlay,alpha,frame,1-alpha,0,frame)

            x_movement, y_movement = camera_movement_per_frame[frame_num]
            frame = cv2.putText(frame,f"Camera Movement X: {x_movement:.2f}",(10,30), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),3)
            frame = cv2.putText(frame,f"Camera Movement Y: {y_movement:.2f}",(10,60), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),3)

            output_frames.append(frame)

        return output_frames

# %%
from ultralytics import YOLO
import supervision as sv
import pickle
import os
import numpy as np
import pandas as pd
import cv2
import sys
sys.path.append('../')

class Tracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.tracker = sv.ByteTrack()

    def add_position_to_tracks(sekf,tracks):
        for object, object_tracks in tracks.items():
            for frame_num, track in enumerate(object_tracks):
                for track_id, track_info in track.items():
                    bbox = track_info['bbox']
                    if object == 'ball':
                        position= get_center_of_bbox(bbox)
                    else:
                        position = get_foot_position(bbox)
                    tracks[object][frame_num][track_id]['position'] = position

    def interpolate_ball_positions(self,ball_positions):
        ball_positions = [x.get(1,{}).get('bbox',[]) for x in ball_positions]
        df_ball_positions = pd.DataFrame(ball_positions,columns=['x1','y1','x2','y2'])

        # Interpolate missing values
        df_ball_positions = df_ball_positions.interpolate()
        df_ball_positions = df_ball_positions.bfill()

        ball_positions = [{1: {"bbox":x}} for x in df_ball_positions.to_numpy().tolist()]

        return ball_positions

    def detect_frames(self, frames):
        batch_size=4
        detections = []
        for i in range(0,len(frames),batch_size):
            detections_batch = self.model.predict(frames[i:i+batch_size],conf=0.1)
            detections += detections_batch
        return detections

    def get_object_tracks(self, frames, read_from_stub=False, stub_path=None):

        if read_from_stub and stub_path is not None and os.path.exists(stub_path):
            with open(stub_path,'rb') as f:
                tracks = pickle.load(f)
            return tracks

        detections = self.detect_frames(frames)

        tracks={
            "players":[],
            "referees":[],
            "ball":[]
        }

        for frame_num, detection in enumerate(detections):
            cls_names = detection.names
            cls_names_inv = {v:k for k,v in cls_names.items()}

            # Covert to supervision Detection format
            detection_supervision = sv.Detections.from_ultralytics(detection)

            # Convert GoalKeeper to player object
            for object_ind , class_id in enumerate(detection_supervision.class_id):
                if cls_names[class_id] == "goalkeeper":
                    detection_supervision.class_id[object_ind] = cls_names_inv["player"]

            # Track Objects
            detection_with_tracks = self.tracker.update_with_detections(detection_supervision)

            tracks["players"].append({})
            tracks["referees"].append({})
            tracks["ball"].append({})

            for frame_detection in detection_with_tracks:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]
                track_id = frame_detection[4]

                if cls_id == cls_names_inv['player']:
                    tracks["players"][frame_num][track_id] = {"bbox":bbox}

                if cls_id == cls_names_inv['referee']:
                    tracks["referees"][frame_num][track_id] = {"bbox":bbox}

            for frame_detection in detection_supervision:
                bbox = frame_detection[0].tolist()
                cls_id = frame_detection[3]

                if cls_id == cls_names_inv['ball']:
                    tracks["ball"][frame_num][1] = {"bbox":bbox}

        if stub_path is not None:
            os.makedirs(os.path.dirname(stub_path), exist_ok=True)
            with open(stub_path,'wb') as f:
                pickle.dump(tracks,f)

        return tracks

    def draw_ellipse(self,frame,bbox,color,track_id=None):
        y2 = int(bbox[3])
        x_center, _ = get_center_of_bbox(bbox)
        width = get_bbox_width(bbox)

        cv2.ellipse(
            frame,
            center=(x_center,y2),
            axes=(int(width), int(0.35*width)),
            angle=0.0,
            startAngle=-45,
            endAngle=235,
            color = color,
            thickness=2,
            lineType=cv2.LINE_4
        )

        rectangle_width = 40
        rectangle_height=20
        x1_rect = x_center - rectangle_width//2
        x2_rect = x_center + rectangle_width//2
        y1_rect = (y2- rectangle_height//2) +15
        y2_rect = (y2+ rectangle_height//2) +15

        if track_id is not None:
            cv2.rectangle(frame,
                          (int(x1_rect),int(y1_rect) ),
                          (int(x2_rect),int(y2_rect)),
                          color,
                          cv2.FILLED)

            x1_text = x1_rect+12
            if track_id > 99:
                x1_text -=10

            cv2.putText(
                frame,
                f"{track_id}",
                (int(x1_text),int(y1_rect+15)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0,0,0),
                2
            )

        return frame

    def draw_traingle(self,frame,bbox,color):
        y= int(bbox[1])
        x,_ = get_center_of_bbox(bbox)

        triangle_points = np.array([
            [x,y],
            [x-10,y-20],
            [x+10,y-20],
        ])
        cv2.drawContours(frame, [triangle_points],0,color, cv2.FILLED)
        cv2.drawContours(frame, [triangle_points],0,(0,0,0), 2)

        return frame

    def draw_team_ball_control(self,frame,frame_num,team_ball_control):
        # Draw a semi-transparent rectaggle
        overlay = frame.copy()
        cv2.rectangle(overlay, (1350, 850), (1900,970), (255,255,255), -1 )
        alpha = 0.4
        cv2.addWeighted(overlay, alpha, frame, 1 - alpha, 0, frame)

        team_ball_control_till_frame = team_ball_control[:frame_num+1]
        # Get the number of time each team had ball control
        team_1_num_frames = team_ball_control_till_frame[team_ball_control_till_frame==1].shape[0]
        team_2_num_frames = team_ball_control_till_frame[team_ball_control_till_frame==2].shape[0]
        team_1 = team_1_num_frames/(team_1_num_frames+team_2_num_frames)
        team_2 = team_2_num_frames/(team_1_num_frames+team_2_num_frames)

        cv2.putText(frame, f"Team 1 Ball Control: {team_1*100:.2f}%",(1400,900), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 3)
        cv2.putText(frame, f"Team 2 Ball Control: {team_2*100:.2f}%",(1400,950), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 3)

        return frame

    def draw_annotations(self,video_frames, tracks,team_ball_control):
        output_video_frames= []
        for frame_num, frame in enumerate(video_frames):
            frame = frame.copy()

            player_dict = tracks["players"][frame_num]
            ball_dict = tracks["ball"][frame_num]
            referee_dict = tracks["referees"][frame_num]

            # Draw Players
            for track_id, player in player_dict.items():
                color = player.get("team_color",(0,0,255))
                frame = self.draw_ellipse(frame, player["bbox"],color, track_id)

                if player.get('has_ball',False):
                    frame = self.draw_traingle(frame, player["bbox"],(0,0,255))

            # Draw Referee
            for _, referee in referee_dict.items():
                frame = self.draw_ellipse(frame, referee["bbox"],(0,255,255))

            # Draw ball
            for track_id, ball in ball_dict.items():
                frame = self.draw_traingle(frame, ball["bbox"],(0,255,0))


            # Draw Team Ball Control
            frame = self.draw_team_ball_control(frame, frame_num, team_ball_control)

            output_video_frames.append(frame)

        return output_video_frames
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2
import sys
sys.path.append('../')

class SpeedAndDistance_Estimator():
    def __init__(self):
        self.frame_window=5
        self.frame_rate=24

    def add_speed_and_distance_to_tracks(self,tracks):
        total_distance= {}

        for object, object_tracks in tracks.items():
            if object == "ball" or object == "referees":
                continue
            number_of_frames = len(object_tracks)
            for frame_num in range(0,number_of_frames, self.frame_window):
                last_frame = min(frame_num+self.frame_window,number_of_frames-1 )

                for track_id,_ in object_tracks[frame_num].items():
                    if track_id not in object_tracks[last_frame]:
                        continue

                    start_position = object_tracks[frame_num][track_id]['position_transformed']
                    end_position = object_tracks[last_frame][track_id]['position_transformed']

                    if start_position is None or end_position is None:
                        continue

                    distance_covered = measure_distance(start_position,end_position)
                    time_elapsed = (last_frame-frame_num)/self.frame_rate
                    speed_meteres_per_second = distance_covered/time_elapsed
                    speed_km_per_hour = speed_meteres_per_second*3.6

                    if object not in total_distance:
                        total_distance[object]= {}

                    if track_id not in total_distance[object]:
                        total_distance[object][track_id] = 0

                    total_distance[object][track_id] += distance_covered

                    for frame_num_batch in range(frame_num,last_frame):
                        if track_id not in tracks[object][frame_num_batch]:
                            continue
                        tracks[object][frame_num_batch][track_id]['speed'] = speed_km_per_hour
                        tracks[object][frame_num_batch][track_id]['distance'] = total_distance[object][track_id]

    def draw_speed_and_distance(self,frames,tracks):
        output_frames = []
        for frame_num, frame in enumerate(frames):
            for object, object_tracks in tracks.items():
                if object == "ball" or object == "referees":
                    continue
                for _, track_info in object_tracks[frame_num].items():
                   if "speed" in track_info:
                       speed = track_info.get('speed',None)
                       distance = track_info.get('distance',None)
                       if speed is None or distance is None:
                           continue

                       bbox = track_info['bbox']
                       position = get_foot_position(bbox)
                       position = list(position)
                       position[1]+=40

                       position = tuple(map(int,position))
                       cv2.putText(frame, f"{speed:.2f} km/h",position,cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,0),2)
                       cv2.putText(frame, f"{distance:.2f} m",(position[0],position[1]+20),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,0),2)
            output_frames.append(frame)

        return output_frames

# %%
import cv2
import numpy as np

def main():
    # Read Video
    video_frames = read_video('/content/drive/MyDrive/football-detection/08fd33_4.mp4')

    # Initialize Tracker
    tracker = Tracker('/content/drive/MyDrive/football-detection/best.pt')

    tracks = tracker.get_object_tracks(video_frames,
                                       read_from_stub=True,
                                       stub_path='/content/drive/MyDrive/football-detection/stubs/track_stubs.pkl')
    # Get object positions
    tracker.add_position_to_tracks(tracks)

    # camera movement estimator
    camera_movement_estimator = CameraMovementEstimator(video_frames[0])
    camera_movement_per_frame = camera_movement_estimator.get_camera_movement(video_frames,
                                                                                read_from_stub=True,
                                                                                stub_path='/content/drive/MyDrive/football-detection/stubs/camera_movement_stub.pkl')
    camera_movement_estimator.add_adjust_positions_to_tracks(tracks,camera_movement_per_frame)


    # View Trasnformer
    view_transformer = ViewTransformer()
    view_transformer.add_transformed_position_to_tracks(tracks)

    # Interpolate Ball Positions
    tracks["ball"] = tracker.interpolate_ball_positions(tracks["ball"])

    # Speed and distance estimator
    speed_and_distance_estimator = SpeedAndDistance_Estimator()
    speed_and_distance_estimator.add_speed_and_distance_to_tracks(tracks)

    # Assign Player Teams
    team_assigner = TeamAssigner()
    team_assigner.assign_team_color(video_frames[0],
                                    tracks['players'][0])

    for frame_num, player_track in enumerate(tracks['players']):
        for player_id, track in player_track.items():
            team = team_assigner.get_player_team(video_frames[frame_num],
                                                 track['bbox'],
                                                 player_id)
            tracks['players'][frame_num][player_id]['team'] = team
            tracks['players'][frame_num][player_id]['team_color'] = team_assigner.team_colors[team]


    # Assign Ball Aquisition
    player_assigner =PlayerBallAssigner()
    team_ball_control= []
    for frame_num, player_track in enumerate(tracks['players']):
        ball_bbox = tracks['ball'][frame_num][1]['bbox']
        assigned_player = player_assigner.assign_ball_to_player(player_track, ball_bbox)

        if assigned_player != -1:
            tracks['players'][frame_num][assigned_player]['has_ball'] = True
            team_ball_control.append(tracks['players'][frame_num][assigned_player]['team'])
        else:
            team_ball_control.append(team_ball_control[-1])
    team_ball_control= np.array(team_ball_control)

    ## Draw object Tracks
    output_video_frames = tracker.draw_annotations(video_frames, tracks,team_ball_control)

    ## Draw Camera movement
    output_video_frames = camera_movement_estimator.draw_camera_movement(output_video_frames,camera_movement_per_frame)

    ## Draw Speed and Distance
    speed_and_distance_estimator.draw_speed_and_distance(output_video_frames,tracks)

    # Save video
    save_video(output_video_frames, '/content/drive/MyDrive/football-detection/output_videos/output_video.avi')

if __name__ == '__main__':
    main()
